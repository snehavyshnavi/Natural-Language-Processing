# %% [markdown]
# <a href="https://colab.research.google.com/github/snehavyshnavi/Natural-Language-Processing/blob/main/NLP_program9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from collections import defaultdict,Counter
from nltk.util import bigrams
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagest')
nltk.download('averaged_perceptron_tagger_eng')
text="""That morning,the old man decided to run across the canel
 but the run was more difficult than he held expected.
 He noticed that the children were playing near the river,\
 and that made him smile."""
print("===INPUT PARAGRAPH ===\n")
print(text)w
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Error loading universal_tagest: Package 'universal_tagest'
# [nltk_data]     not found in index
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# ===INPUT PARAGRAPH ===
#
# That morning,the old man decided to run across the canel
#  but the run was more difficult than he held expected.
#  He noticed that the children were playing near the river, and that made him smile.
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %%
import nltk
from collections import defaultdict, Counter
from nltk.util import bigrams

# Download required
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
nltk.download('averaged_perceptron_tagger_eng')


# Step: 1

text = """ The morning, the old man decided to run across the playground
           but the run was more difficult than he had expected.
           He noticed that the children were playing near, the river, /
           and that made his smile. """

print("=== Input Paragraph =====\n")
print(text)

# Step:2

words = nltk.word_tokenize(text)
tagged_words = nltk.pos_tag(words, tagset = 'universal')


print("\n === (a) POS TAGGING ====")
print("Each word is assinged a grammatical tag: \n")


# Step 3: WOrd with Greatest Number of Distinct tags

word_tags = defaultdict(set)
for word, tag in tagged_words:
  word_tags[word.lower()].add(tag)

word_with_most_tags= max(word_tags.items(), key= lambda x: len(x[1]))


print("\n === (b) WORD WITH MOST DISTINCT TAGS ====")

print(f"Word: {word_with_most_tags[0]}")
print(f"Word: {word_with_most_tags[1]}")
print("This word is used in different grammatical roles")


# Step:  4  Tags in Decreasing frequency

all_tags = [tag for _, tag in tagged_words]
tag_freq = Counter(all_tags)


print("\n===(c) TAG  FREQUENCY ====")

print("Tags sorted by decreasing frequnecy: \n")
for tag, freq in tag_freq.most_common():
  print(f"{tag:5} -> {freq}")

print("\n Common tags")

tag_meanings = {
    "NOUN" : "NOUN(person, place, thing, idea)",
    "VERB" : "VERB (action or state)",
    "ADJ" : "Adverb (describes or noun)",
    "DET" : "Determiner (the, a , this , that)",
    "PRON" : "Pronoun (he, she, they)",
    'ADP' : "Adpostion (in , on, at, with)",
    'CONJ' : "Conjunction (and, or, but)",
    "NUM" : "Number (one, two, 100)",
    "PRT" : "Particle (up, off, to)",
    "." : "Punctuation or sentence boundary",
    "X" : "Other(foreign words, typos)"
}


for tag in list(tag_freq.keys()):
  if tag in tag_meanings:
    print(f"{tag:5} -> {tag_meanings[tag]}")


# Step: 5 Most common Tags After a NOUN

tagged_bigrams = list(bigrams(tagged_words))

after_noun = Counter(tag for (w1,t1), (w2,t2) in tagged_bigrams if t1 == 'NOUN')

print("\n === (d) TAGS AFTER NOUNs ====")


for tag, freq in after_noun.most_common():
  print(f"{tag:5} -> {freq}")

print("- VERB after NOUN : subject-verb relation (e.g, 'AI holds). ")
print("-ADP after NOUN: preposistions (e.g., 'world in').")
print("-DET after NOUN: determiner for another noun (e.g., 'world the').")
print("-Another NOUN: compond nouns (e.g., 'AI systems').")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# === Input Paragraph =====
#
#  The morning, the old man decided to run across the playground
#            but the run was more difficult than he had expected.
#            He noticed that the children were playing near, the river, /
#            and that made his smile.
#
#  === (a) POS TAGGING ====
# Each word is assinged a grammatical tag:
#
#
#  === (b) WORD WITH MOST DISTINCT TAGS ====
# Word: run
# Word: {'NOUN', 'VERB'}
# This word is used in different grammatical roles
#
# ===(c) TAG  FREQUENCY ====
# Tags sorted by decreasing frequnecy:
#
# VERB  -> 9
# NOUN  -> 8
# DET   -> 6
# .     -> 5
# ADP   -> 4
# PRON  -> 3
# ADJ   -> 2
# CONJ  -> 2
# ADV   -> 2
# PRT   -> 1
#
#  Common tags
# DET   -> Determiner (the, a , this , that)
# NOUN  -> NOUN(person, place, thing, idea)
# .     -> Punctuation or sentence boundary
# ADJ   -> Adverb (describes or noun)
# VERB  -> VERB (action or state)
# PRT   -> Particle (up, off, to)
# ADP   -> Adpostion (in , on, at, with)
# CONJ  -> Conjunction (and, or, but)
# PRON  -> Pronoun (he, she, they)
#
#  === (d) TAGS AFTER NOUNs ====
# PRON  -> 8
# - VERB after NOUN : subject-verb relation (e.g, 'AI holds).
# -ADP after NOUN: preposistions (e.g., 'world in').
# -DET after NOUN: determiner for another noun (e.g., 'world the').
# -Another NOUN: compond nouns (e.g., 'AI systems').
